# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumartofficial-commits/AI-First-programming/blob/main/Python_Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. What is Inheritance?
#
# Inheritance allows a class (child) to acquire the properties and methods of another class (parent).
#
# **✔ Why use inheritance?**
#
# Reusability
#
# Extensibility
#
# Clean & structured code
#
# Reduces duplication

# %% [markdown]
# # 🔥 2. Basic Inheritance Example

# %%
class Parent:
    def display(self):
        print("I am Parent class")

class Child(Parent):
    pass

c = Child()
c.display()

# %% [markdown]
# # 3. Types of Inheritance in Python
#
# Python supports 5 types of inheritance:
#
# **1️⃣ Single Inheritance**

# %%
Parent
  ↓
Child

# %%
class A:
    def showA(self):
        print("A")

class B(A):
    def showB(self):
        print("B")

# %% [markdown]
# **2️⃣ Multilevel Inheritance**

# %%
A → B → C

# %%
class A:
    pass

class B(A):
    pass

class C(B):
    pass

# %% [markdown]
# **3️⃣ Multiple Inheritance**

# %% [markdown]
#     A     B
#       ↓ ↓
#         C

# %%
class A:
    pass

class B:
    pass

class C(A, B):
    pass

# %% [markdown]
# **4️⃣ Hierarchical Inheritance**

# %% [markdown]
#       Parent
#       /   \
# Child1   Child2

# %%
class Parent:
    pass

class Child1(Parent):
    pass

class Child2(Parent):
    pass

# %% [markdown]
# **5️⃣ Hybrid Inheritance**
#
# (Combination of multiple inheritance types)
#
# Python supports hybrid inheritance, but avoids issues using MRO (Method Resolution Order).

# %% [markdown]
# # 🔥 4. Method Overriding
#
# Child class redefines the method of the parent.

# %%
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

d = Dog()
d.sound()

# %% [markdown]
# # 5. super() Keyword
#
# Used to call parent class methods and constructors.
#
# ✔ Example with constructor:

# %%
class A:
    def __init__(self):
        print("A constructor")

class B(A):
    def __init__(self):
        super().__init__()
        print("B constructor")

# %% [markdown]
# # 6. Constructor in Inheritance
# ✔ Scenario 1: Parent has constructor
#
# Child inherits it automatically.
#
# ✔ Scenario 2: Child has constructor
#
# Parent constructor must be called using super().

# %% [markdown]
# # 7. MRO (Method Resolution Order)
#
# Python uses C3 Linearization Algorithm.
#
# Check order using:

# %%
print(ClassName.mro())
 #or
help(ClassName)

# %% [markdown]
# # 🔥 8. Real-Life Example: Employee Inheritance

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def show(self):
        print("Name:", self.name, "| Salary:", self.salary)

class Manager(Employee):
    def __init__(self, name, salary, bonus):
        super().__init__(name, salary)
        self.bonus = bonus

    def show(self):
        super().show()
        print("Bonus:", self.bonus)

m = Manager("Santhosh", 40000, 5000)
m.show()

# %% [markdown]
# # 9. Key Differences: Overloading vs Overriding

# %% [markdown]
# | Feature           | Overloading       | Overriding |
# | ----------------- | ----------------- | ---------- |
# | Same method name? | Yes               | Yes        |
# | Same parameters?  | No                | Yes        |
# | Works at          | Compile time      | Runtime    |
# | Python support?   | No direct support | Yes        |

# %% [markdown]
# # 10. Access Modifiers in Inheritance

# %% [markdown]
# | Modifier  | Syntax | Access                |
# | --------- | ------ | --------------------- |
# | Public    | `x`    | Anywhere              |
# | Protected | `_x`   | Within class/subclass |
# | Private   | `__x`  | Only inside class     |

# %% [markdown]
# # 11. Practice Coding Exercises
#
# ✔ Easy
#
# Create a Parent → Child class and print values.
#
# Make a Vehicle class and derive Car from it.
#
# ✔ Medium
#
# Create a Person → Student → CollegeStudent chain.
#
# Override a method in the child class.
#
# ✔ Hard
#
# Create multiple inheritance example with MRO check.
#
# Create BankAccount → SavingsAccount & CurrentAccount showing interest rate differences.

# %% [markdown]
# # 12. Advanced Interview Questions
#
# 1️⃣ What is inheritance?
#
# 2️⃣ Types of inheritance in Python?
#
# 3️⃣ What is method overriding?
#
# 4️⃣ How does Python resolve method calls in multiple inheritance?
#
# 5️⃣ What is the use of super()?
#
# 6️⃣ What is MRO?
#
# 7️⃣ Does Python support constructor overloading?
#
# 8️⃣ Difference between inheritance and composition?
#
# 9️⃣ What is diamond problem? How Python solves it?
#
# 🔟 How to prevent inheritance? (final, NotImplementedError)

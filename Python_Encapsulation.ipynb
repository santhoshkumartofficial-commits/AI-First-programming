# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumartofficial-commits/AI-First-programming/blob/main/Python_Encapsulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. What is Encapsulation?
#
# Encapsulation = binding data + methods into a single unit (class)
# and restricting direct access to variables.
#
# 📌 Encapsulation provides:
#
# Data protection
#
# Controlled access
#
# Security
#
# Better code structure

# %% [markdown]
# # 2. Access Modifiers in Python
#
# Python has 3 levels of access control:
#
# | Type          | Syntax       | Meaning                              |
# | ------------- | ------------ | ------------------------------------ |
# | **Public**    | `variable`   | Accessible everywhere                |
# | **Protected** | `_variable`  | Accessible within class + subclasses |
# | **Private**   | `__variable` | Accessible only inside the class     |

# %% [markdown]
# # 3. Public Members

# %%
class Student:
    def __init__(self, name):
        self.name = name  # public variable

s = Student("Kumar")
print(s.name)

# %% [markdown]
# # 4. Protected Members
#
# (Convention-based, not enforced strictly)

# %%
class A:
    def __init__(self):
        self._value = 10

class B(A):
    def display(self):
        print("Value:", self._value)

b = B()
b.display()

# %% [markdown]
# # 5. Private Members (Strong Encapsulation)
#
# Private variables are name-mangled internally.

# %%
class Account:
    def __init__(self, balance):
        self.__balance = balance  # private

    def show(self):
        print("Balance:", self.__balance)

acc = Account(5000)
acc.show()

# %% [markdown]
# ❌ Can't access directly:
# acc.__balance → Error
#
# ✔ Internal name becomes:
# _Account__balance

# %% [markdown]
# # 6. Private Methods

# %%
class Demo:
    def __secret(self):
        print("This is private")

    def public(self):
        self.__secret()

d = Demo()
d.public()

# %% [markdown]
# # 7. Getter and Setter Methods
#
# Used for controlled access to private variables.

# %%
class Person:
    def __init__(self, age):
        self.__age = age

    # getter
    def get_age(self):
        return self.__age

    # setter
    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("Invalid age")

p = Person(25)
print(p.get_age())
p.set_age(30)

# %% [markdown]
# # 8. Encapsulation with Property Decorators (Modern Way)
#
# ✔ Using @property (Best Practice)

# %%
class Employee:
    def __init__(self, salary):
        self.__salary = salary

    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self, value):
        if value > 0:
            self.__salary = value
        else:
            print("Invalid salary")

e = Employee(10000)
print(e.salary)
e.salary = 15000

# %% [markdown]
# # 9. Real-Life Example: ATM Encapsulation

# %%
class ATM:
    def __init__(self, pin, balance):
        self.__pin = pin
        self.__balance = balance

    def check_balance(self, pin):
        if pin == self.__pin:
            return self.__balance
        else:
            return "Wrong PIN"

    def deposit(self, pin, amount):
        if pin == self.__pin:
            self.__balance += amount
        else:
            print("Wrong PIN")

atm = ATM(1234, 5000)
print(atm.check_balance(1234))
atm.deposit(1234, 2000)

# %% [markdown]
# Encapsulated fields:
# ✔ __pin
# ✔ __balance

# %% [markdown]
# # 🔥 10. Encapsulation Summary Table
#
# | Feature       | Public     | Protected          | Private           |
# | ------------- | ---------- | ------------------ | ----------------- |
# | Access Level  | Everywhere | Class + Subclasses | Only within class |
# | Syntax        | `var`      | `_var`             | `__var`           |
# | Name Mangling | No         | No                 | Yes               |

# %% [markdown]
# # 11. Interview Questions
#
# 1️⃣ What is encapsulation?
#
# 2️⃣ Why is encapsulation needed?
#
# 3️⃣ Difference between encapsulation & abstraction?
#
# 4️⃣ What are access modifiers in Python?
#
# 5️⃣ How does private variable name-mangling work?
#
# 6️⃣ When to use getters and setters?
#
# 7️⃣ What is the use of @property decorator?
#
# 8️⃣ Can private members be accessed outside?
#
# 9️⃣ Is encapsulation strict in Python?
#
# 🔟 Explain encapsulation with a real-world example.
#
# ------------------------------------
# # 📝 12. Practice Coding Challenges
#
# ✔ Easy
#
# Create a class with private balance and public display.
#
# Use a protected variable and access it in a child class.
#
# ✔ Medium
#
# Create a class BankAccount with private balance and deposit/withdraw methods.
#
# Implement getter & setter for private “marks” variable.
#
# ✔ Hard
#
# Create a Student Management System with encapsulated name, age, marks.
#
# Implement encapsulation using @property with validation rules.

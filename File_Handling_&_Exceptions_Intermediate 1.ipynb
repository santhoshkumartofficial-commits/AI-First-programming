# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshkumartofficial-commits/AI-First-programming/blob/main/File_Handling_%26_Exceptions_Intermediate%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python File Handling
#
# File handling allows Python to create, read, write, and delete files.
#
# Python uses the built-in function:

# %%
open("filename", "mode")

# %% [markdown]
# # 📂 File Modes in Python
#
#
# | Mode   | Description                                    |
# | ------ | ---------------------------------------------- |
# | `"r"`  | Read (default) – file must exist               |
# | `"w"`  | Write – creates new file / overwrites existing |
# | `"a"`  | Append – add data to end of file               |
# | `"x"`  | Create – creates file, error if exists         |
# | `"r+"` | Read + Write                                   |
# | `"w+"` | Write + Read                                   |
# | `"a+"` | Append + Read                                  |

# %% [markdown]
# # 🟦 1. Creating & Writing to a File (w)

# %%
file = open("demo.txt", "w")
file.write("Hello Python!\nWelcome to file handling.")
file.close()

# %% [markdown]
# # 🟦 2. Appending to a File (a)

# %%
file = open("demo.txt", "a")
file.write("\nThis line is appended.")
file.close()

# %% [markdown]
# # 🟦 3. Reading a File (r)

# %%
file = open("demo.txt", "r")
content = file.read()
print(content)
file.close()

# %% [markdown]
# # ✔ Read entire file

# %%
file = open("demo.txt", "r")
content = file.read()
print(content)
file.close()

# %% [markdown]
# # ✔ Read first 10 characters

# %%
print(file.read(10))

# %% [markdown]
# # ✔ Read line by line

# %%
file = open("demo.txt", "r")
for line in file:
    print(line)
file.close()

# %% [markdown]
# # ✔ Read all lines into a list

# %%
lines = file.readlines()
print(lines)

# %% [markdown]
# # 4. Using with open() – Best Practice

# %%
with open("demo.txt", "r") as f:
    print(f.read())

# %% [markdown]
# # 🟦 5. Writing List of Lines

# %%
lines = ["Python\n", "Java\n", "C++\n"]

with open("languages.txt", "w") as f:
    f.writelines(lines)

# %% [markdown]
# # 🟦 6. File Existence Check
#
# Use os module:

# %%
import os

if os.path.exists("demo.txt"):
    print("File exists")
else:
    print("Not found")

# %% [markdown]
# # 🟦 7. Deleting a File

# %%
import os
os.remove("demo.txt")

# %% [markdown]
# # 🟦 8. Deleting a Folder

# %%
os.rmdir("myfolder")

# %% [markdown]
# ⭐ Mini Programs
#
#
# ✔ Program 1: Count number of words in a file[link text](https://)

# %%
with open("demo.txt", "r") as f:
    words = f.read().split()
    print("Total words:", len(words))

# %% [markdown]
# ✔ Program 2: Copy content from one file to another

# %%
with open("source.txt", "r") as src:
    with open("target.txt", "w") as trg:
        trg.write(src.read())

# %% [markdown]
# ✔ Program 3: Count lines, words, characters

# %%
with open("demo.txt", "r") as f:
    text = f.read()
    lines = text.split("\n")
    words = text.split()
    print("Lines:", len(lines))
    print("Words:", len(words))
    print("Characters:", len(text))

# %% [markdown]
# ✔ Program 4: Reverse file content

# %%
with open("demo.txt", "r") as f:
    data = f.read()

with open("reverse.txt", "w") as f:
    f.write(data[::-1])

# %% [markdown]
# Python File Handling Interview Questions (Top 30)
# 🔹 1. What is file handling in Python? Why is it used?
#
# 🔹 2. What are the different file modes in Python?
#
#
# Examples: "r", "w", "a", "x", "r+", "w+", "a+"
#
#
# 🔹 3. What is the difference between read(), readline(), and readlines()?
#
# 🔹 4. What is the purpose of with open() in Python?
#
# Why is it preferred over open()?
#
#
# 🔹 5. What happens if you open a file that does not exist using "r" mode?
#
# 🔹 6. What will "w" mode do if the file already exists?
#
# 🔹 7. Write a Python program to count the number of lines in a file.
#
# 🔹 8. Write a Python program to copy contents from one file to another.
#
# 🔹 9. How do you check if a file exists in Python?
#
# 🔹 10. Difference between text mode and binary mode?
#
# "r" vs "rb"
#
#
# 🔹 11. What does seek() and tell() do?
#
# 🔹 12. Write a program to count words in a file.
#
# 🔹 13. How to append content to an existing file?
#
# 🔹 14. Write a program to read a file line-by-line.
#
# 🔹 15. What is file pointer? How much does it move when reading?
#
# 🔹 16. Write a program to find how many characters a file contains.
#
# 🔹 17. How do you handle exceptions in file handling?
#
# Example: File not found
#
#
# 🔹 18. What is the difference between truncate() and write()?
#
# 🔹 19. What is flush() in file handling?
#
# 🔹 20. Write a program to remove all blank lines from a file.
#
# 🔹 21. Write a program to reverse the content of a text file.
#
# 🔹 22. What is the difference between close() and using “with” block?
#
# 🔹 23. Write a program to store even numbers in a separate file.
#
# 🔹 24. What is the use of "x" mode?
#
#
# 🔹 25. Write a program to merge two files into a third file.
#
# 🔹 26. What happens if you open a binary file in text mode?
#
# 🔹 27. What is the difference between "a" and "a+" modes?
#
# 🔹 28. How to read only the first 10 characters from a file?
#
# 🔹 29. Write a program to replace a word in a file.
#
# Example: replace "Python" with "Java"
#
#
# 🔹 30. How to check file size in Python?

# %% [markdown]
# # Python File Exceptions
#
# When working with files, errors can occur such as file not found, permission issues, or read/write errors. Python handles these using exceptions.
#
# Below are the most important file-related exceptions.

# %% [markdown]
# # 1. FileNotFoundError
#
# Occurs when you try to open a file that doesn’t exist.
#
# Example:

# %%
try:
    f = open("unknown.txt", "r")
except FileNotFoundError:
    print("Error: File not found!")

# %% [markdown]
# # 2. PermissionError
#
# Raised when you don’t have permission to read/write the file.
#
# Example:

# %%
try:
    f = open("/root/secret.txt", "r")
except PermissionError:
    print("Error: You don't have permission to access this file.")

# %% [markdown]
# # 3. IsADirectoryError
#
# Occurs when you try to open a directory instead of a file.
#
# Example:

# %%
try:
    f = open("myfolder", "r")
except IsADirectoryError:
    print("Error: Expected a file but found a directory.")

# %% [markdown]
# # 4. NotADirectoryError
#
# Raised when a directory path contains a file instead of a folder.
#
# Example:

# %%
try:
    f = open("file.txt/subfolder/data.txt")
except NotADirectoryError:
    print("Error: A path component is not a directory.")

# %% [markdown]
# # 5. IOError / OSError
#
# General I/O related errors (disk failure, read/write issues).
#
# Example:

# %%
try:
    f = open("file.txt", "w")
    f.write("Hello")
except OSError:
    print("Input/output error occurred!")

# %% [markdown]
# # 6. UnsupportedOperation
#
# Raised when file mode does not support the given operation.
#
# Example:

# %%
try:
    f = open("file.txt", "r")
    f.write("hello")  # Writing in read mode
except UnsupportedOperation:
    print("Error: Cannot write in read mode!")

# %% [markdown]
# # 7. EOFError
#
# Occurs when input() hits end-of-file (rare in normal file operations).
#
# Example:

# %%
try:
    data = input()
except EOFError:
    print("Error: End of file reached unexpectedly.")

# %% [markdown]
# # 8. ValueError (Invalid mode)
#
# Occurs when incorrect mode is used.
#
# Example

# %%
try:
    open("file.txt", "wrongmode")
except ValueError:
    print("Error: Invalid file mode!")

# %% [markdown]
# # 📌 Full Example: Handling Multiple Exceptions

# %%
try:
    with open("data.txt", "r") as f:
        print(f.read())

except FileNotFoundError:
    print("File does not exist!")

except PermissionError:
    print("Permission denied!")

except IsADirectoryError:
    print("Path points to a directory, not a file!")

except OSError:
    print("General OS error occurred!")

# %% [markdown]
# # Best Practice: Always Use try–except for File Handling

# %%
try:
    with open("myfile.txt") as f:
        print(f.read())
except Exception as e:
    print("Error:", e)
